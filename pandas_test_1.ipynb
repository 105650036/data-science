# %%
import pandas as pd
import numpy as np

# %%
myobj=pd.Series([4,7,-5,3])

# %%
myobj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
my_obj2 = pd.Series([8,9,10,11], index=['a','b','c','d'])
my_obj2
# Out:
# a     8
# b     9
# c    10
# d    11
# dtype: int64

# %%
'a' in my_obj2
# Out:
# True

# %%
df = pd.read_csv('F:/class/machine learning/HousePrices_Regression-master/train-v3.csv')

# %%
df.head(3)
# Out:
#            id   price  sale_yr  sale_month  sale_day  bedrooms  bathrooms  \
# 0  5615100330  200000   2015.0         3.0      27.0       4.0        2.0
# 1  8835900086  350000   2014.0         9.0       2.0       4.0        3.0
# 2  9510900270  254000   2014.0        12.0      11.0       3.0        2.0
#
#    sqft_living  sqft_lot  floors  ...  grade  sqft_above  sqft_basement  \
# 0       1900.0    8160.0     1.0  ...    7.0      1900.0            0.0
# 1       3380.0   16133.0     1.0  ...    8.0      2330.0         1050.0
# 2       2070.0    9000.0     1.0  ...    7.0      1450.0          620.0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0    1975.0             0  98022.0  47.2114 -121.986         1280.0
# 1    1959.0             0  98118.0  47.5501 -122.261         2500.0
# 2    1969.0             0  98023.0  47.3085 -122.376         1630.0
#
#    sqft_lot15
# 0        6532
# 1       11100
# 2        7885
#
# [3 rows x 23 columns]

# %%
sector=df.groupby("price")

# %%
df.shape
# Out:
# (12967, 23)

# %%
df[['price','sqft_living']][0:3]
# Out:
#     price  sqft_living
# 0  200000       1900.0
# 1  350000       3380.0
# 2  254000       2070.0

# %%
df.insert(3,column="123",value="456")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-63fbb3712b61> in <module>
# ----> 1 df.insert(3,column="123",value="456")
#       2 df.head(3)
#
# F:\anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3574         self._ensure_valid_index(value)
#    3575         value = self._sanitize_column(column, value, broadcast=False)
# -> 3576         self._data.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3577
#    3578     def assign(self, **kwargs):
#
# F:\anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1171         if not allow_duplicates and item in self.items:
#    1172             # Should this be a different kind of error??
# -> 1173             raise ValueError("cannot insert {}, already exists".format(item))
# ...

# %%
df.head(3)
# Out:
#            id   price  sale_yr  123  sale_month  sale_day  bedrooms  \
# 0  5615100330  200000   2015.0  456         3.0      27.0       4.0
# 1  8835900086  350000   2014.0  456         9.0       2.0       4.0
# 2  9510900270  254000   2014.0  456        12.0      11.0       3.0
#
#    bathrooms  sqft_living  sqft_lot  ...  grade  sqft_above  sqft_basement  \
# 0        2.0       1900.0    8160.0  ...    7.0      1900.0            0.0
# 1        3.0       3380.0   16133.0  ...    8.0      2330.0         1050.0
# 2        2.0       2070.0    9000.0  ...    7.0      1450.0          620.0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0    1975.0             0  98022.0  47.2114 -121.986         1280.0
# 1    1959.0             0  98118.0  47.5501 -122.261         2500.0
# 2    1969.0             0  98023.0  47.3085 -122.376         1630.0
#
#    sqft_lot15
# 0        6532
# 1       11100
# 2        7885
#
# [3 rows x 24 columns]

# %%
df.sort_values('price')
# Out:
#                id    price      sale_yr  123   sale_month     sale_day  \
# 12436  3421079032    75000  2318.826340  456 -2732.603730 -9068.910256
# 3994     40000362    78000  2112.203963  456  -873.002331 -2899.756410
# 3387   8658300340    80000  2097.347319  456  -739.292541 -2456.179487
# 2743   3028200080    81000  2081.585082  456  -597.432401 -1985.564103
# 8963   3883800011    82000  2233.822844  456 -1967.572261 -6530.948718
# ...           ...      ...          ...  ...          ...          ...
# 494    1924059029  4668000  2026.539627  456  -102.023310  -342.064103
# 687    1247600105  5110800  2031.263403  456  -144.537296  -483.102564
# 5027   8907500070  5350000  2137.487179  456 -1100.551282 -3654.641026
# 10509  2470100110  5570000  2271.662005  456 -2308.124709 -7660.717949
# 922    9808700762  7062500  2037.015152  456  -196.303030  -654.833333
#
#          bedrooms   bathrooms   sqft_living      sqft_lot  ...       grade  \
# ...

# %%
df.drop("123",axis=1)
# Out:
#                id   price      sale_yr   sale_month     sale_day    bedrooms  \
# 0      5615100330  200000  2015.000000     3.000000    27.000000    4.000000
# 1      8835900086  350000  2014.000000     9.000000     2.000000    4.000000
# 2      9510900270  254000  2014.000000    12.000000    11.000000    3.000000
# 3      2621600015  175000  2015.000000     4.000000    30.000000    3.000000
# 4      8078350090  619000  2015.000000     3.000000    31.000000    3.000000
# ...           ...     ...          ...          ...          ...         ...
# 12962  9253900354  580000  2331.700466 -2848.470862 -9453.294872  909.548951
# 12963  9510300130  598000  2331.724942 -2848.691142 -9454.025641  909.618881
# 12964  1105000373  252500  2331.749417 -2848.911422 -9454.756410  909.688811
# 12965  3629990280  497000  2331.773893 -2849.131702 -9455.487179  909.758741
# 12966  9521100586  479000  2331.798368 -2849.351981 -9456.217949  909.828671
#
# ...

# %%
seriesObj = pd.Series(range(10),index=['a', 'a', 'b', 'b', 'b','c','c','c','c','c'])

# %%
df = pd.DataFrame(np.random.randn(4,2),index=['a', 'a', 'b', 'b'])

# %%
df
# Out:
#           0         1
# a -0.666169  0.481262
# a  0.397711  0.148769
# b  1.282611 -1.317002
# b  0.551464 -2.371624

# %%
df.ix['b']
# Out:
# F:\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#           0         1
# b  1.282611 -1.317002
# b  0.551464 -2.371624

# %%
df['price']==200000
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12962    False
# 12963    False
# 12964    False
# 12965    False
# 12966    False
# Name: price, Length: 12967, dtype: bool

# %%
fliter=(df['price']==200000)
df[fliter]
# Out:
#                id   price      sale_yr   sale_month     sale_day    bedrooms  \
# 0      5615100330  200000  2015.000000     3.000000    27.000000    4.000000
# 7      7812800995  200000  2014.000000     9.000000     5.000000    2.000000
# 44     2349300060  200000  2015.525641    -2.897436   -13.217949    6.192308
# 219    1446404015  200000  2019.808858   -41.446387  -141.102564   18.430070
# 528    2968801105  200000  2027.371795  -109.512821  -366.910256   40.038462
# 1346   7831800505  200000  2047.392774  -289.701632  -964.679487   97.241259
# 1982    257000037  200000  2062.959207  -429.799534 -1429.448718  141.716783
# 2111    421000555  200000  2066.116550  -458.215618 -1523.717949  150.737762
# 2387   1723049008  200000  2072.871795  -519.012820 -1725.410256  170.038462
# 3156   1821059067  200000  2091.693473  -688.407925 -2287.371795  223.814685
# 3869   2781250520  200000  2109.144522  -845.467366 -2808.410256  273.674825
# ...

# %%
fliter2=df['floors']>10

# %%
df[df['price'].between(100000,300000)]
# Out:
#                id   price      sale_yr   sale_month     sale_day    bedrooms  \
# 0      5615100330  200000  2015.000000     3.000000    27.000000    4.000000
# 2      9510900270  254000  2014.000000    12.000000    11.000000    3.000000
# 3      2621600015  175000  2015.000000     4.000000    30.000000    3.000000
# 5      1061400180  240000  2015.000000     1.000000     6.000000    3.000000
# 6      7697870600  158000  2014.000000     9.000000     9.000000    3.000000
# ...           ...     ...          ...          ...          ...         ...
# 12951  7129304200  200000  2331.431235 -2846.047786 -9445.256410  908.779720
# 12954  2023039045  295000  2331.504662 -2846.708625 -9447.448718  908.989511
# 12960  2215900900  295000  2331.651515 -2848.030303 -9451.833333  909.409091
# 12961  2115720500  286000  2331.675991 -2848.250583 -9452.564103  909.479021
# 12964  1105000373  252500  2331.749417 -2848.911422 -9454.756410  909.688811
#
# ...

# %%
type(sector)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
sector.size()
# Out:
# price
# 75000      1
# 78000      1
# 80000      1
# 81000      1
# 82000      1
#           ..
# 4668000    1
# 5110800    1
# 5350000    1
# 5570000    1
# 7062500    1
# Length: 2994, dtype: int64

# %%
sector.get_group(200000).head()
# Out:
#              id   price      sale_yr  sale_month    sale_day   bedrooms  \
# 0    5615100330  200000  2015.000000    3.000000   27.000000   4.000000
# 7    7812800995  200000  2014.000000    9.000000    5.000000   2.000000
# 44   2349300060  200000  2015.525641   -2.897436  -13.217949   6.192308
# 219  1446404015  200000  2019.808858  -41.446387 -141.102564  18.430070
# 528  2968801105  200000  2027.371795 -109.512821 -366.910256  40.038462
#
#      bathrooms   sqft_living      sqft_lot     floors  ...     grade  \
# 0     2.000000   1900.000000    8160.00000   1.000000  ...  7.000000
# 7     1.000000    790.000000    5985.00000   1.000000  ...  6.000000
# 44    2.916667   2828.589744   37889.15385   4.782051  ...  6.679487
# 219   6.893939   6291.876457  153565.98950  20.079254  ...  4.843823
# 528  13.916667  12407.051280  357818.23080  47.089744  ...  1.602564
#
#        sqft_above  sqft_basement     yr_built  yr_renovated      zipcode  \
# ...

# %%
col = ['class','name','hbd']
data = [['class0', 'user0', '1993-10-01'],
        ['class0', 'user1', '1992-10-02'],
        ['class1', 'user2', '1990-10-01'],
        ['class2', 'user3', '1983-10-03'],
        ['class1', 'user4', '1991-10-02'],
        ['class0', 'user5', '2001-10-03']]
frame = pd.DataFrame(data,columns=col)

# %%
frame_class = frame.groupby('class')

# %%
frame_class.groups
# Out:
# {'class0': Int64Index([0, 1, 5], dtype='int64'),
#  'class1': Int64Index([2, 4], dtype='int64'),
#  'class2': Int64Index([3], dtype='int64')}

# %%
frame_class.get_group("class1")
# Out:
#     class   name         hbd
# 2  class1  user2  1990-10-01
# 4  class1  user4  1991-10-02

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
                      'foo', 'bar', 'foo', 'foo'],
                   'B' : ['one', 'one', 'two', 'three',
                          'two', 'two', 'one', 'three'],
                   'C' : np.random.randn(8),
                   'D' : np.random.randn(8)})

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one -0.217189 -0.655504
# 1  bar    one  0.146930 -1.175005
# 2  foo    two -0.400306  0.052396
# 3  bar  three  0.635782  1.038228
# 4  foo    two -0.398912 -0.520798
# 5  bar    two  0.061311 -0.315440
# 6  foo    one  0.537899  0.713335
# 7  foo  three -0.145274 -1.250642

# %%
a=df.groupby(['A','B'])

# %%
a.sum()
# Out:
#                   C         D
# A   B
# bar one    0.146930 -1.175005
#     three  0.635782  1.038228
#     two    0.061311 -0.315440
# foo one    0.320710  0.057831
#     three -0.145274 -1.250642
#     two   -0.799218 -0.468402
